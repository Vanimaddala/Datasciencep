# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanimaddala/Datasciencep/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Webscraping using Python

# %%
import yfinance as yf

tesla_data = yf.download('TSLA')

tesla_data.reset_index(inplace=True)

print(tesla_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
print(tesla_data.tail())
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 3476 2024-04-22  140.559998  144.440002  138.800003  142.050003  142.050003
# 3477 2024-04-23  143.330002  147.259995  141.110001  144.679993  144.679993
# 3478 2024-04-24  162.839996  167.970001  157.509995  162.130005  162.130005
# 3479 2024-04-25  158.960007  170.880005  158.360001  170.179993  170.179993
# 3480 2024-04-26  168.850006  172.119995  166.369995  168.289993  168.289993
#
#          Volume
# 3476  107097600
# 3477  124545100
# 3478  181178000
# 3479  126427500
# 3480  108896700

# %%
import yfinance as yf

gme_data = yf.download('GME')

gme_data.reset_index(inplace=True)
print(gme_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date     Open     High      Low    Close  Adj Close    Volume
# 0 2002-02-13  2.40625  2.51500  2.38125  2.51250   1.691667  76216000
# 1 2002-02-14  2.54375  2.54875  2.48125  2.50000   1.683251  11021600
# 2 2002-02-15  2.50000  2.50625  2.46250  2.48750   1.674834   8389600
# 3 2002-02-19  2.47500  2.47500  2.34375  2.38750   1.607504   7410400
# 4 2002-02-20  2.40000  2.46875  2.38125  2.46875   1.662210   6892800

# %%
print(gme_data.tail())
# Out:
#            Date   Open   High    Low  Close  Adj Close   Volume
# 5584 2024-04-22  10.41  10.45  10.01  10.01      10.01  3261000
# 5585 2024-04-23  10.05  10.28  10.01  10.16      10.16  2511800
# 5586 2024-04-24  10.16  10.94  10.16  10.93      10.93  4829600
# 5587 2024-04-25  10.70  11.21  10.48  11.21      11.21  4903800
# 5588 2024-04-26  11.18  12.19  11.00  11.90      11.90  7626200

# %%
import matplotlib.pyplot as plt
def make_graph(Data, title):
  plt.title(title)
  plt.xlabel('Date')
  plt.ylabel('Price (USD)')
  plt.plot(Data['Date'], Data['Close'], label='Close', color='red')
  plt.show()
make_graph(tesla_data, title='Tesla Stock')

# %%
import matplotlib.pyplot as plt
def make_graph(Data, title):
  plt.title(title)
  plt.xlabel('Date')
  plt.ylabel('Price (USD)')
  plt.plot(Data['Date'], Data['Close'], label='Close', color='blue')
  plt.show()
make_graph(gme_data, title='GME Data')
